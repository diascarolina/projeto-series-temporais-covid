# %% [markdown]
# # Limpeza dos Dados

# %% [markdown]
# Fonte: https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/ef3bd0b8-b605-474b-9ae5-c97390c197a8

# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Dados Sobre Casos e Óbitos da COVID-19

# %%
df = pd.read_csv('../data/caso_full.csv.gz')

# %%
df
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 2331707      Tupirama       1721257.0  2021-06-29                202126
# 2331708    Tupiratins       1721307.0  2021-06-29                202126
# 2331709  Wanderlândia       1722081.0  2021-06-29                202126
# 2331710       Xambioá       1722107.0  2021-06-29                202126
# 2331711           NaN            17.0  2021-06-29                202126
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
dados_ce = df.query('state == "CE"')

# %%
dados_ce = dados_ce.query('place_type == "state"').drop('city', axis = 1)

# %%
dados_ce
# Out:
#         city_ibge_code        date  epidemiological_week  \
# 263065            23.0  2020-03-16                202012
# 263068            23.0  2020-03-17                202012
# 263072            23.0  2020-03-18                202012
# 263077            23.0  2020-03-19                202012
# 263084            23.0  2020-03-20                202012
# ...                ...         ...                   ...
# 343646            23.0  2021-06-25                202125
# 343832            23.0  2021-06-26                202125
# 344018            23.0  2021-06-27                202126
# 344204            23.0  2021-06-28                202126
# 344390            23.0  2021-06-29                202126
#
#         estimated_population  estimated_population_2019  is_last  is_repeated  \
# 263065             9187103.0                  9132078.0    False        False
# 263068             9187103.0                  9132078.0    False        False
# ...

# %%
#dados_ce = dados_ce.set_index('date').rename_axis(None)

# %%
colunas = ['date', 'new_confirmed', 'new_deaths', 'last_available_confirmed', 'last_available_deaths',
           'epidemiological_week', 'estimated_population_2019']

# %%
dados_ce = dados_ce[colunas]

# %%
dados_ce
# Out:
#               date  new_confirmed  new_deaths  last_available_confirmed  \
# 263065  2020-03-16              9           0                         9
# 263068  2020-03-17              1           0                        10
# 263072  2020-03-18              9           0                        19
# 263077  2020-03-19              5           0                        24
# 263084  2020-03-20             44           0                        68
# ...            ...            ...         ...                       ...
# 343646  2021-06-25           3424          48                    876055
# 343832  2021-06-26           2610          68                    878665
# 344018  2021-06-27           1753          22                    880418
# 344204  2021-06-28            775          12                    881193
# 344390  2021-06-29           4296         100                    885489
#
#         last_available_deaths  epidemiological_week  estimated_population_2019
# ...

# %%
colunas_pt = ['data', 'novos_casos', 'novos_obitos', 'total_casos', 'total_mortes',
             'semana_epidemiologica', 'pop_estimada_2019']

# %%
dados_ce.columns = colunas_pt

# %%
dados_ce
# Out:
#               data  novos_casos  novos_obitos  total_casos  total_mortes  \
# 263065  2020-03-16            9             0            9             0
# 263068  2020-03-17            1             0           10             0
# 263072  2020-03-18            9             0           19             0
# 263077  2020-03-19            5             0           24             0
# 263084  2020-03-20           44             0           68             0
# ...            ...          ...           ...          ...           ...
# 343646  2021-06-25         3424            48       876055         22352
# 343832  2021-06-26         2610            68       878665         22420
# 344018  2021-06-27         1753            22       880418         22442
# 344204  2021-06-28          775            12       881193         22454
# 344390  2021-06-29         4296           100       885489         22554
#
#         semana_epidemiologica  pop_estimada_2019
# ...

# %%
dados_ce.to_csv('../data/dados_covid_ce.csv')
